# %% [markdown]
# # Digital cut-up
# by Anna Lin

# %% [markdown]
# ## Phrases from signs, in 5

# %%
import random
words = [
    "美",
    "抗衰除皺 永久脱司",
    "脫痣瘦身",
    "212-608-0907 212-964-3510",
    "華",
    "茶",
    "EE",
    "NO PARKING",
    "DON'T EVEN",
    "THINK OF",
    "BLOCKING DRIVEWAY",
    "DEP",
    "EAGLE TRAIL PANORAMA",
    "TERRACE-",
    "1/4 MILE",
    "BIG BEAR LAKE",
    "Highway 18",
    "→ Ski Resorts",
    "Visitor Center",
    "S",
    "MINOR FIGURES",
    "BARISTA OAT",
    "AUTERONT",
    "Artisanal",
    "wash fold",
    "DIVE CARE",
    "SUPPLY",
    "Claverie PET EXPRESSL VE CARE",
    "ILIS RICE AJN ROMAT",
    "SUFFLY",
    "MONDAY-THURSDAY 7AM-7PM FRIDAY-SUNDAY 7AM-7PM",
    "ONDAY-THUR SEAT FR 7AM-7PM",
    "letcher",
    "ON RED",
    "R WASH",
    "ARWASH",
    "ASTRO DINER COFFEE SHOP OPEN 24 HOURS",
    "ASTRO FAMILY RESTAURANT CARHOP SERVICE 323 663 9241",
    "SPEED",
    "LIMIT",
    "35",
    "Roth Line",
    "Bitburger Red I",
    "2366",
    "No Lion",
    "SPATEN",
    "früh MAIN ENTRANCE",
    "Glendale BI",
    "DO NO",
    "ENTER",
    "WRON WAY",
    "ONE WA"
]

random.shuffle(words)

for (i, w) in enumerate(words):
    print(w, end=' ', flush=True)
    if (i % 5 == 0):
        print('\n')
        if (random.random() > 0.8):
            print('\n')
# Out:
# ONDAY-THUR SEAT FR 7AM-7PM
#
# 1/4 MILE EE 華 → Ski Resorts Claverie PET EXPRESSL VE CARE
#
# R WASH früh MAIN ENTRANCE 2366 脫痣瘦身 ASTRO FAMILY RESTAURANT CARHOP SERVICE 323 663 9241
#
# DO NO SUPPLY BARISTA OAT Highway 18 SPATEN
#
# S 35 ARWASH 抗衰除皺 永久脱司 NO PARKING
#
# AUTERONT DON'T EVEN ONE WA letcher EAGLE TRAIL PANORAMA
#
#
#
# BLOCKING DRIVEWAY DIVE CARE 212-608-0907 212-964-3510 TERRACE- SUFFLY
#
# ON RED No Lion Visitor Center ENTER 美
#
# DEP wash fold Roth Line Glendale BI MINOR FIGURES
#
# Bitburger Red I WRON WAY LIMIT 茶 MONDAY-THURSDAY 7AM-7PM FRIDAY-SUNDAY 7AM-7PM
#
# ASTRO DINER COFFEE SHOP OPEN 24 HOURS BIG BEAR LAKE ILIS RICE AJN ROMAT THINK OF Artisanal
#
# SPEED

# %% [markdown]
# ## Words from signs, individually

# %%
import random
words = [
    "美",
    "抗衰除皺",
    "永久脱司",
    "脫痣瘦身",
    "212-608-0907",
    "212-964-3510",
    "華",
    "茶",
    "EE",
    "NO",
    "PARKING",
    "DON'T",
    "EVEN",
    "THINK",
    "OF",
    "BLOCKING",
    "DRIVEWAY",
    "DEP",
    "EAGLE",
    "TRAIL",
    "PANORAMA",
    "TERRACE-",
    "1/4",
    "MILE",
    "BIG",
    "BEAR",
    "LAKE",
    "Highway",
    "18",
    "→",
    "Ski",
    "Resorts",
    "Visitor",
    "Center",
    "S",
    "MINOR",
    "FIGURES",
    "BARISTA",
    "OAT",
    "AUTERONT",
    "Artisanal",
    "wash",
    "fold",
    "DIVE",
    "CARE",
    "SUPPLY",
    "Claverie",
    "PET",
    "EXPRESSL",
    "VE",
    "CARE",
    "ILIS",
    "RICE",
    "AJN",
    "ROMAT",
    "SUFFLY",
    "MONDAY-THURSDAY",
    "7AM-7PM",
    "FRIDAY-SUNDAY",
    "7AM-7PM",
    "ONDAY-THUR",
    "SEAT",
    "FR",
    "7AM-7PM",
    "letcher",
    "ON",
    "RED",
    "R",
    "WASH",
    "ARWASH",
    "ASTRO",
    "DINER",
    "COFFEE",
    "SHOP",
    "OPEN",
    "24",
    "HOURS",
    "ASTRO",
    "FAMILY",
    "RESTAURANT",
    "CARHOP",
    "SERVICE",
    "323",
    "663",
    "9241",
    "SPEED",
    "LIMIT",
    "35",
    "Roth",
    "Line",
    "Bitburger",
    "Red",
    "I",
    "2366",
    "No",
    "Lion",
    "SPATEN",
    "früh",
    "MAIN",
    "ENTRANCE",
    "Glendale",
    "BI",
    "DO",
    "NO",
    "ENTER",
    "WRON",
    "WAY",
    "ONE",
    "WA"
]

random.shuffle(words)

for (i, w) in enumerate(words):
    print(w, end=' ', flush=True)
    if (i % 7 == 0):
        print('\n')
        if (random.choice([True, False])):
            print('\n')
# Out:
# DRIVEWAY
#
#
#
# Center FAMILY THINK 華 FRIDAY-SUNDAY Ski 7AM-7PM
#
#
#
# R Glendale CARE Red Highway Lion MINOR
#
# CARE 212-608-0907 ONE ASTRO 1/4 永久脱司 SEAT
#
#
#
# Claverie CARHOP EE EAGLE PARKING 7AM-7PM HOURS
#
#
#
# RESTAURANT SUPPLY ASTRO → AJN Bitburger Artisanal
#
# BEAR SPATEN SPEED MONDAY-THURSDAY PET WRON FR
#
# SHOP 7AM-7PM 663 S 212-964-3510 PANORAMA 323
#
#
#
# 24 TRAIL AUTERONT DEP Resorts COFFEE LAKE
#
#
#
# ENTER wash BI ARWASH MILE BLOCKING WAY
#
# NO ONDAY-THUR DO 美 OPEN 抗衰除皺 WA
#
# 脫痣瘦身 9241 2366 Visitor OAT No Line
#
#
#
# 35 FIGURES LIMIT TERRACE- früh RICE ILIS
#
#
#
# BARISTA 18 fold OF MAIN letcher VE
#
# 茶 Roth ON EXPRESSL RED ENTRANCE DON'T
#
# ROMAT SERVICE EVEN BIG DIVE SUFFLY I
#
# NO DINER WASH

# %%
import random
words = [
    "美",
    "抗衰除皺 永久脱司",
    "脫痣瘦身",
    "212-608-0907 212-964-3510",
    "華",
    "茶",
    "EE",
    "NO PARKING",
    "DON'T EVEN",
    "THINK OF",
    "BLOCKING DRIVEWAY",
    "DEP",
    "EAGLE TRAIL PANORAMA",
    "TERRACE-",
    "1/4 MILE",
    "BIG BEAR LAKE",
    "Highway 18",
    "→ Ski Resorts",
    "Visitor Center",
    "S",
    "MINOR FIGURES",
    "BARISTA OAT",
    "AUTERONT",
    "Artisanal",
    "wash fold",
    "DIVE CARE",
    "SUPPLY",
    "Claverie PET EXPRESSL VE CARE",
    "ILIS RICE AJN ROMAT",
    "SUFFLY",
    "MONDAY-THURSDAY 7AM-7PM FRIDAY-SUNDAY 7AM-7PM",
    "ONDAY-THUR SEAT FR 7AM-7PM",
    "letcher",
    "ON RED",
    "R WASH",
    "ARWASH",
    "ASTRO DINER COFFEE SHOP OPEN 24 HOURS",
    "ASTRO FAMILY RESTAURANT CARHOP SERVICE 323 663 9241",
    "SPEED",
    "LIMIT",
    "35",
    "Roth Line",
    "Bitburger Red I",
    "2366",
    "No Lion",
    "SPATEN",
    "früh MAIN ENTRANCE",
    "Glendale BI",
    "DO NO",
    "ENTER",
    "WRON WAY",
    "ONE WA"
]

random.shuffle(words)

line_lengths = [1, 3, 5, 7, 7, 5, 3, 1]
lindex = 0

for (i, w) in enumerate(words):
    LL = line_lengths[lindex]
    print((' '*(30-LL))+w, end=' ', flush=True)
    print('\n')
    lindex = lindex + 1 if lindex < len(line_lengths)-1 else 0
# Out:
#                              THINK OF
#
#                            MINOR FIGURES
#
#                          美
#
#                        1/4 MILE
#
#                        抗衰除皺 永久脱司
#
#                          ASTRO DINER COFFEE SHOP OPEN 24 HOURS
#
#                            Bitburger Red I
#
#                              ON RED
#
#                              ILIS RICE AJN ROMAT
#
#                            ASTRO FAMILY RESTAURANT CARHOP SERVICE 323 663 9241
#
#                          Artisanal
#
#                        wash fold
#
#                        letcher
#
#                          Claverie PET EXPRESSL VE CARE
#
#                            ARWASH
#
#                              35
#
#                              ONDAY-THUR SEAT FR 7AM-7PM
#
#                            S
#
#                          SUPPLY
#
#                        R WASH
#
#                        EE
#
#                          NO PARKING
#
# ...
