# %% [markdown]
# # Final
# Mirrored double entendres
# by anna y lin

# %%
import sys
import random as random
from collections import Counter
import json
# !{sys.executable} -m pip install PyDictionary
from PyDictionary import PyDictionary
import string
import math
# Out:
# Requirement already satisfied: PyDictionary in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: goslate in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from PyDictionary) (1.5.4)
# Requirement already satisfied: bs4 in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from PyDictionary) (0.0.1)
# Requirement already satisfied: click in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from PyDictionary) (8.0.4)
# Requirement already satisfied: requests in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from PyDictionary) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from bs4->PyDictionary) (4.11.1)
# Requirement already satisfied: futures in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from goslate->PyDictionary) (3.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from requests->PyDictionary) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from requests->PyDictionary) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from requests->PyDictionary) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from requests->PyDictionary) (2.0.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/annaaa/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->bs4->PyDictionary) (2.3.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # a set of unique words
# I took The Waves by Virginia Woolf, and cross-compared that with a set of the most common English words from the corpora Github repo--and created a new list of less common English words from The Waves.

# %%
book = open("./thewaves.txt").read()
text = book.replace("\n", " ").split(" ")
text = [t.strip(string.punctuation) for t in text]
t1 = set(text)
t2 = None
with open('./common.json') as commonWords:
    t2 = json.load(commonWords)["commonWords"]
    t2.extend(['', 'her', 'him', 'my', 'hers', 'his', 'mine', 'I', 'your', 'yours', 'they', 'their', 'theirs']) # extra special words to omit from final words list
words = [x for x in t1 if x not in t2]
print(words)
print(len(words))
# Out:
# ['dived', 'undone', 'marshy', 'desolate', 'abrupt', 'soaked', 'swamp', 'menaces', 'bathroom', 'wheeled', 'sighing', 'candelabra', 'cares', 'red-edged', 'dissolving', 'haunted', 'flowers', 'wasps', 'reddened', 'shops', 'covers', 'disarming', 'Unhappy', 'reconciliation', 'clay-coloured', 'continuance', 'pitch-pine', 'By', 'visions', 'thickening', 't', 'Hebrides', 'building', 'core', 'Mounting', 'wastes', 'heron', 'motionless', 'proboscis', 'meet--what', 'washer-woman', 'dramatic', 'armchairs', 'connected', 'Bubbles', 'killed', 'imbue', "hairdresser's", 'Love', 'woven', 'sensual-looking', 'childhood', 'swells', 'propped', 'vegetation', 'perpetual', 'sews', 'street--no', 'like"--but', 'monotonous', 'disease', 'Louis', 'Ajax', 'translate', 'disparate', 'dried', 'springs', 'assembled', 'riot', 'stormy', 'ashamed', 'somebody--with', 'life--a', 'rainier', 'dips', 'irregularly', 'provided', 'incantation', 'America', 'waistcoat', 'ignored', 'lassitude', 'military', 'spending', 'stertorously', 'obliquity', 'Active', 'unequally', 'saying', 'mechanism', 'vision', 'emotion', 'plumbers', 'effort', 'spurs', 'masters', 'attached', 'skirts', 'warmth', 'contains', 'slap-dash', 'Images', 'accent--and', 'solid', 'showers', 'glasses', 'spoon', 'bird', 'gymnasium', 'view--one', 'vestments', "Burchard's", 'snatches', 'six-sided', 'grassy', 'censers', 'momentary', 'ruthlessly', 'lovers', 'swooned', 'buying', 'flung', 'boil', 'huge', 'racing', 'downfall', 'ferocious', 'Think', 'lambs', 'many-faceted', 'boyish', 'externals', 'cowls', 'Trafalgar', 'magnificently', 'body--this', 'comer', 'materials', 'lips', 'clump', 'fanwise', 'bees', 'Am', 'He', "doctor's", 'kissed', 'enmity', 'pyramid', 'consent', 'speaking', 'remarkable', 'While', 'reproved', 'eyeless', 'pagan', 'scarcely', 'translucency', 'billowing', 'soles', "Wickham's", 'sunset', 'vice', 'density', 'bores', 'innocent', 'muzzle', 'discussing', "don't", 'chimney', 'splinters', 'miles', 'imperceptibly', 'coral', 'Far', 'Consume', 'silver-leaved', 'applying', 'laden', 'skirt', 'mast', 'Monday', 'paper-knife', 'acquainted', 'unknown', 'encounter', 'Other', 'purview', 'tattered', 'speaking--the', 'purrs', 'dashes', 'wars', 'grappled', 'unshadowed', 'swift', 'sways', 'redden', 'opposition', "other's", 'hoping', 'sleeper', 'sharp', 'despised', 'stories', 'Which', 'begins', 'coverings', 'gibe', 'apricot', 'shapely', 'uncounted', 'Clear-cut', 'sad', 'knows', 'privilege', 'interpret', 'fifty', 'thought', 'successful', 'restaurant', 'finick', 'insignificant', 'cathedral', 'concealed', 'possessions', 'red--even', 'Certain', 'freedom', 'seemliness', 'tumblers', 'beauties', 'feather', 'walled', 'laurels', 'Greenwich', 'insist', 'tassels', 'expands', 'inland', 'privilege--not', 'printing', 'Throwing', 'fingers', 'cups', 'angles', 'impressed', 'sugar-tongs', 'extent', 'These', 'assaulting', 'Byron', 'plenty', 'furled', 'indent', 'knife', 'approval', 'gusty', 'dragonfly', 'prince', 'narrow', 'prolong', 'tinkles', 'canary', 'bubble--images', 'deny', 'incandescent', 'fired', 'delicious', 'hunt', 'bee', 'utterly', 'marches', 'loaves', 'astonished', 'explanation', 'flight', 'enters', 'soberly', "Bernard's", 'pattern', 'image--the', 'respects', 'duchess', 'wardrobe', 'afraid', 'streaks', 'string', 'snug', 'burble', 'envelop', 'struck', 'inherit', 'shiny', 'verandahs', 'violins', 'music--a', 'Barker', 'thrush', 'jealousies', 'setter', 'deluded', 'fan', 'sweet', 'thick-leaved', 'deftly', 'strands', 'counterpanes', 'shower', 'magnificence', 'bristle', 'outstretched', 'Instinctively', 'joints', 'secrets', 'meetings', 'dressing-table', 'sheets', 'competitors', 'sweep', 'gaping', 'wafted', 'gorse', 'Euripides', 'dining--so', 'whoever', 'troubling', 'covet', 'Dark', 'queens', 'Age', 'bedroom', 'crowed', 'twitching', 'Englishman', 'compressed', 'sands', 'passer-by', 'spirals', 'compunction', 'plunge', 'bullock-cart', 'faithful', 'Oppose', 'paces', 'chopper', 'clapping', 'sensibility', 'gongs', 'Blenheim', 'merge', 'hateful', 'k ...
# 8834

# %% [markdown]
# ## words that appeared at least twice
# I ran into an issue where a lot of the double entendres I found in the text were only used once. Since I wanted to make the poem out of two different usages of the word, it would require the word to have appeared more than once in the text, so I narrowed the list further.

# %%
count = Counter(book.split(" "))
words = [w for w in words if count[w] > 1]
print(len(words))
# Out:
# 2845

# %% [markdown]
# # finding double entendres
# using the sample word "china" which is closest to what I mean by a double entendre--it has multiple entries in the Noun category<br><br>
# I'll use this as a rule for determining which words in my word list are double entendres--if they have more than 2 (to be safe) entries in the Noun category then I'll count it as a double entendre

# %%
dictionary=PyDictionary("china")

print(dictionary.printMeanings()) 
print(dictionary.getMeanings())
# Out:
# China:
# Noun:
# a communist nation that covers a vast territory in eastern Asia; the most populous country in the world
# high quality porcelain originally made only in China
# a government on the island of Taiwan established in 1949 by Chiang Kai-shek after the conquest of mainland China by the Communists led by Mao Zedong
# dishware made of high quality porcelain
# None
# {'china': {'Noun': ['a communist nation that covers a vast territory in eastern Asia; the most populous country in the world', 'high quality porcelain originally made only in China', 'a government on the island of Taiwan established in 1949 by Chiang Kai-shek after the conquest of mainland China by the Communists led by Mao Zedong', 'dishware made of high quality porcelain']}}

# %% [markdown]
# # getting the double entendres
# the dictionary API takes a lot longer than I expected, so I'll shorten the call by only calling the API until I get at least 5 double entendres

# %%
doubleEntendres = []
random.shuffle(words)
wordIndex = 0
while len(doubleEntendres) < 5 and wordIndex < len(words):
    word = words[wordIndex]
    dictionary=PyDictionary(word)
    meanings = dictionary.getMeanings()
    if meanings and meanings[word] and "Noun" in meanings[word] and len(meanings[word]["Noun"]) > 3:
        doubleEntendres.append(word)
        print(word + ' is a double entendre')
#         print(meanings)
    else:
        print(word + ' is NOT a double entendre')
    wordIndex += 1
print(doubleEntendres)
# dictionary=PyDictionary(words[1])
# dictionary.getMeanings()
# dictionary.printMeanings()
# Out:
# commercial is NOT a double entendre
# Error: The Following Error occured: list index out of range
# many-pleated is NOT a double entendre
# spurt is NOT a double entendre
# wreathe is NOT a double entendre
# babies is a double entendre
# {'babies': {'Noun': ['a very young child (birth to 1 year', 'the youngest member of a group (not necessarily young', 'an immature childish person', 'an unborn child; a human fetus', 'a very young mammal', 'a project of personal concern to someone'], 'Verb': ['treat with excessive indulgence']}}
# felt is NOT a double entendre
# engulfed is NOT a double entendre
# remade is NOT a double entendre
# crowd is NOT a double entendre
# rapidity is NOT a double entendre
# Painters is a double entendre
# {'Painters': {'Noun': ['an artist who paints', 'a worker who is employed to cover objects with paint', 'a line that is attached to the bow of a boat and used for tying up (as when docking or towing', 'large American feline resembling a lion']}}
# writing is a double entendre
# {'writing': {'Noun': ['the act of creating written works', 'the work of a writer; anything expressed in letters of the alphabet (especially when considered from the point of view of style and effect', '(usually plural', 'letters or symbols that are written or imprinted on a surface to represent the sounds or words of a language', 'the activity of putting something in written form'], 'Verb': ['produce a literary work', 'communicate or express by writing', 'communicate (with', 'write music', 'mark or trace on a surface', 'record data on a computer', 'write or name the letters that comprise the conventionally accepted form of (a word or part of a word', 'create code, write a computer program']}}
# jangled is NOT a double entendre
# vases is NOT a double entendre
# arid is NOT a double entendre
# actuaries is NOT a double entendre
# fits is a double entendre
# {'fits': {'Noun': ['a display of bad temper', 'a sudden uncontrollable attack', 'the manner in which something fits', 'a sudden flurry of activity (often for no obvious reason'], 'Verb': ['be agreeable or acceptable to', 'be the right size or shape; fit correctly or as desired', 'make fit', 'insert or adjust several objects or people', 'be compatible, similar or consistent; coincide in their characteristics', 'conform to some shape or size', 'provide with (something', 'fill, satisfy or meet a want or need or condtion ro restriction', 'make correspond or harmonize']}}
# bicycles is NOT a double entendre
# wrinkle is NOT a double entendre
# directly is NOT a double entendre
# appalling is NOT a double entendre
# masts is a double entendre
# {'masts': {'Noun': ['a vertical spar for supporting sails', 'nuts of forest trees (as beechnuts and acorns', 'nuts of forest trees used as feed for swine', 'any sturdy upright pole']}}
# ['babies', 'Painters', 'writing', 'fits', 'masts']

# %% [markdown]
# # taking the words and placing it back into context
# then I took the words and found lines with those words in Woolf's text, and created 'mirror' images out of them

# %%
entendresList = ['bolt','frame','barks','cutting','fibre','gutter','hoop','earth']
# entendresList=doubleEntendres
tabs =  [10,9,8,7,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6]
tabs2 = [14,14,11,8,5,5,5,5,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4]
fib =   [0, 1, 5, 8, 13, 13, 13, 13, 13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13,13]
mir_dict = {"a":"ɒ","b": "d","c": "ɔ","d": "b","e": "ɘ","f": "ʇ","g": "ǫ","h": "ʜ","i": "i","j": "Ⴑ","k": "ʞ","l": "l","m": "m","n": "n","o": "o","p": "q","q": "p","r": "ɿ","s": "ƨ","t": "ƚ","u": "u","v": "v","w": "w","x": "x","y": "y","z": "z"}
for entend in entendresList:
    print('\033[1m' + entend +  '\033[0m')
    eindex = book.find(entend)
    left = book[eindex-150:eindex+500].replace('\n',' ')
    nindex = book.find(entend,eindex+200)
    right = book[nindex-150:nindex+500].replace('\n',' ')
    leftIndex = 0
    rightIndex = 0
    for i,t in enumerate(tabs):
        # LEFT SIDE
        inc = tabs[i]+fib[i]
        print('_' * t, end='')
        if (i == 9):
            print('\033[1m' + left[leftIndex:leftIndex+inc] +  '\033[0m', end='')
        else:
            print(left[leftIndex:leftIndex+inc], end='')
        leftIndex += inc
        
        # RIGHT SIDE
        print('_' * tabs2[i], end='')
