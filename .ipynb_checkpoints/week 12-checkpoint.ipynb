# %% [markdown]
# # Week 12
# The poems i love
# by anna lin

# %%
import sys
# !{sys.executable} -m pip install pronouncing

# %%
import pronouncing as pr

# %%
import random as random

# %%
pr.phones_for_word("mysterious")
# Out:
# ['M IH0 S T IH1 R IY0 AH0 S']

# %%
from collections import Counter
print(Counter([i for i in "anna"]))
# Out:
# Counter({'a': 2, 'n': 2})

# %%
poem = open("./poem.txt").read().replace("\n", " ").split(" ");
phones = []
phones_list = []
for item in poem:
    item.lower()
    p = pr.phones_for_word(item)
    p = p[0] if p else ''
#     print(p)
#     if len(p)>2:
#         print(p[-3:])
    phone = p.split()
    if len(phone)>2:
        print(phone[-2:])
#     phones.extend(phone)
#     print(item, phone)
#     phones_list.extend(pronouncing.phones_for_word(item))
#     pronouncing.stresses(phones_list[:-1])
# Out:
# ['AE1', 'L']
# ['EH1', 'R']
# ['R', 'T']
# ['AO1', 'R']
# ['L', 'IY0']
# ['N', 'D']
# ['AO1', 'R']
# ['AH1', 'F']
# ['D', 'Z']
# ['EY1', 'K']
# ['IH0', 'NG']
# ['D', 'Z']
# ['N', 'D']
# ['IY1', 'S']
# ['AE1', 'TH']
# ['R', 'T']
# ['AY2', 'M']
# ['AA1', 'T']
# ['AH0', 'N']
# ['N', 'D']
# ['AH0', 'N']
# ['IH1', 'Z']
# ['L', 'D']
# ['AH0', 'N']
# ['N', 'D']
# ['ER0', 'IY0']
# ['EH1', 'R']
# ['AH1', 'M']
# ['EH1', 'R']
# ['AY2', 'M']
# ['N', 'S']
# ['IH0', 'NG']
# ['R', 'S']
# ['AH1', 'T']
# ['AH0', 'L']
# ['M', 'ER0']
# ['AE1', 'L']
# ['AA1', 'T']
# ['AO1', 'R']
# ['UW1', 'Z']
# ['AH0', 'N']
# ['AE1', 'T']
# ['EH1', 'R']
# ['AO1', 'R']
# ['AE1', 'L']
# ['EH1', 'TH']
# ['AE1', 'G']
# ['IH1', 'Z']
# ['EH1', 'N']
# ['AH0', 'L']
# ['N', 'Z']
# ['AY1', 'M']
# ['AO1', 'NG']
# ['EH1', 'N']
# ['AE1', 'N']
# ['IY1', 'DH']
# ['AE1', 'N']
# ['AO1', 'NG']
# ['V', 'Z']
# ['N', 'D']
# ['IH1', 'S']
# ['V', 'Z']
# ['AY1', 'F']

# %%
book = open("pg29461.txt").read().replace("\n", " ").split(" ");
book_phones = []
book_last2_phones = []
book_phones_list = []
for item in book:
    item.lower()
    p = pr.phones_for_word(item)
    p = p[0] if p else ''
    phone = p.split()
    book_phones.extend(phone)
    if len(phone)>2:
        book_last2_phones.extend(phone[-2:])
    else:
        book_last2_phones.extend(phone)
#     print(item, phone)
# print(book_last2_phones)
# Out:
# ['R', 'IY0', 'N', 'Z', 'M', 'D', 'T', 'AH0', 'S', 'ER0', 'AH0', 'L', 'R', 'IY1', 'AH0', 'L', 'N', 'T', 'AH0', 'N', 'T', 'S', 'AH0', 'L', 'AH1', 'V', 'T', 'S', 'AH0', 'N', 'AH0', 'L', 'AH0', 'N', 'AH0', 'M', 'AA1', 'K', 'AE2', 'M', 'AH0', 'L', 'AH0', 'N', 'AH0', 'L', 'AH0', 'N', 'AH0', 'L', 'T', 'S', 'AH0', 'L', 'S', 'ER0', 'IH0', 'NG', 'D', 'Z', 'AH0', 'N', 'AE2', 'T', 'B', 'ER0', 'AH0', 'M', 'IH0', 'NG', 'K', 'T', 'IH0', 'NG', 'AH0', 'N', 'S', 'T', 'AH0', 'L', 'L', 'Z', 'AH0', 'JH', 'ER0', 'D', 'P', 'ER0', 'EY1', 'P', 'D', 'ER0', 'P', 'ER0', 'EY1', 'P', 'N', 'CH', 'T', 'ER0', 'AH0', 'L', 'N', 'S', 'EY1', 'K', 'AH0', 'M', 'HH', 'AY1', 'IY1', 'D', 'AH0', 'L', 'IH0', 'K', 'EY1', 'P', 'L', 'EY1', 'IY1', 'L', 'AY1', 'M', 'AA1', 'K', 'AY1', 'N', 'T', 'ER0', 'T', 'IY0', 'M', 'Z', 'AE1', 'P', 'AH0', 'M', 'AH0', 'M', 'IH0', 'NG', 'N', 'T', 'N', 'S', 'N', 'Z', 'AH0', 'S', 'N', 'Z', 'AH0', 'N', 'AH0', 'L', 'AH0', 'N', 'DH', 'AH0', 'EH1', 'K', 'M', 'D', 'T', 'AH0', 'S', 'ER0', 'AH0', 'L', 'R', 
# ...

# %%
for item in poem:
    item.lower()
    p = pr.phones_for_word(item)
    p = p[0] if p else ''
    phone = p.split()
    if len(phone)>2:
        rr = pr.search((" ").join(phone[-2:]) + '$')
        print(random.choice(rr), end=" ")
    else:
        print(item)
#     print(phone[-2:])
#     print(book_last2_phones)
#     if len(phone)>2 and phone[-2:] in book_last2_phones:
#         print(book[book_last2_phones.index(phone[-2:])], end=" ")
#     elif len(phone)>2 and phone[-2:] not in book_last2_phones:
# #         print(phone[-2:])
# #         print((pr.search(phone[-2:]))
              
#         rr = pr.search(phone)
#         print(random.choice(rr), end=" ")
#     else:
#         print(book[book_last2_phones.index(phone[-1])], end=" ")
# Out:
# al. I
# dispair thee
# to
# a
# summer’s
# day?
# Thou
# neyhart tore precisely armond antiwar temperate:
# fluff wildes do
# shaikh the
# overfunding tends of
# May,
# obtained summer’s
# mcneece vath all
# too
# dukart a
# date;
# everytime too
# scot the
# eye
# of
# consolidation shines,
# unmentioned dissection is
# 'tis greenfield harman dimm'd;
# garmond midcentury glare stum aware overtime declines,
# By
# existence or
# nature’s
# redacting source untrimm'd;
# utt thy
# eagle gemmer perceval swat fade,
# glore underuse goodin of
# landsat flare thou
# ow’st;
# cohr institucional macbeth bagg thou
# wander’st
# in
# wiz shade,
# uren in
# rydell infotron's to
# beim thou
# grow’st:
#
#
#
# So
# luong as
# sheng-fen than breathe or
# eyes
# ruthann see,
#
#
#
# So
# prong outlives this,
# regained hiss rives ex-wife to
# thee.
